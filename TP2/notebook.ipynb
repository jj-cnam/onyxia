# %%
stock = {
    "pains au chocolat": 500,
    "croissants": 400,
    "baguettes": 500,
    "beignets": 200
}

# %%
for produit, quantite in stock.items():
    print(produit, ":", quantite)
# Out:
# pains au chocolat : 500
# croissants : 400
# baguettes : 500
# beignets : 200

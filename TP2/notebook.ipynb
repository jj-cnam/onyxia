# %%
stock = {
    "pains au chocolat": 500,
    "croissants": 400,
    "baguettes": 500,
    "beignets": 200
}

# juste pour tester merge
# 2e test de merge

# test 3

print("ajout d'une nouvelle ligne")

# AJOUT de FEAT 2
